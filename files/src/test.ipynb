# %%
import os

# %%
fpath = "/Users/danielgarcia-barnett/Desktop/Coding/wj_scoring_app/Python/files/data/user-DGB/sub-test_1/IMG_6655.png"

# %%
basename = os.path.basename(fpath)
dirname = os.path.dirname(fpath)

# %%
basename
# Out:
# 'IMG_6655.png'

# %%
dirname
# Out:
# '/Users/danielgarcia-barnett/Desktop/Coding/wj_scoring_app/Python/files/data/user-DGB/sub-test_1'
